# %%
# !pip install fastapi
# Out:
# ...
#      |████████████████████████████████| 55 kB 932 kB/s
# ...
#      |████████████████████████████████| 63 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 2.6 MB 960 kB/s
# ...
#      |████████████████████████████████| 80 kB 1.9 MB/s
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.0.1
#     Uninstalling typing-extensions-4.0.1:
#       Successfully uninstalled typing-extensions-4.0.1
# ...

# %%
# !pip install uvicorn
# Out:
# ...
#      |████████████████████████████████| 54 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.2 MB/s
# ...

# %%
from fastapi import FastAPI
import uvicorn 
app = FastAPI()


@app.get("/ping")

async def ping():
  return "I am alive"


if __name__ == '__main__':
  uvicorn.run(app , host = 'localhost' , port = 8000)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-dd7470020c30> in <module>()
#      11
#      12 if __name__ == '__main__':
# ---> 13   uvicorn.run(app , host = 'localhost' , port = 8000)
#
# /usr/local/lib/python3.7/dist-packages/uvicorn/main.py in run(app, **kwargs)
#     450         Multiprocess(config, target=server.run, sockets=[sock]).run()
#     451     else:
# --> 452         server.run()
#     453     if config.uds:
#     454         os.remove(config.uds)  # pragma: py-win32
#
# /usr/local/lib/python3.7/dist-packages/uvicorn/server.py in run(self, sockets)
#      66         self.config.setup_event_loop()
#      67         if sys.version_info >= (3, 7):
# ---> 68             return asyncio.run(self.serve(sockets=sockets))
#      69         return asyncio.get_event_loop().run_until_complete(self.serve(sockets=sockets))
#      70
#
# ...
